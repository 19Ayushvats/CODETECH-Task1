# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("heart.csv")

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %% [markdown]
# ## Analysing Numerical Data

# %%
sns.displot(df["Age"] , kde = True , color = "blue")
# Out:
# C:\Users\Ankish\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# Hence we can say that maximum number heart disease is found in the age of 40 - 70 years

# %%
sns.displot(x = df["RestingBP"] , kde = True )
# Out:
# C:\Users\Ankish\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# Maximum number of people have there RestingBP in the range 100 - 150 .

# %%
sns.displot(df["Cholesterol"] , kde = True )
# Out:
# C:\Users\Ankish\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.displot(df["MaxHR"] , kde = True)
# Out:
# C:\Users\Ankish\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# Maximum number of people has there maximum HeartRate in the range 120 - 160 .

# %% [markdown]
# ## Analysing categorical data

# %%
df.groupby('Sex').size().plot(kind = "pie" , autopct = "%0.1f"  )
# Out:
# <Axes: >

# %% [markdown]
# Out of all the patients evaulated for test , 79% of them are men and 21% are female

# %%
df.groupby("ChestPainType").size().plot(kind = "pie" , autopct = "%.1f")
# Out:
# <Axes: >

# %% [markdown]
# From all the ChestPain cases evaluated , 54% of the patients has ASY type chest pain , 5% has TA , 22.1 % has NAP type and 18.8% has ATA type

# %%
df.groupby('RestingECG').size().plot(kind = 'pie', autopct = '%.1f', figsize = (6,6))
# Out:
# <Axes: >

# %% [markdown]
# 60% of patients are having normal ECG whereas 20.5 and 19.4% patients have LVT(left ventricular Hypertrophy) and ST respectively

# %%
df.groupby('ST_Slope').size().plot(kind = 'pie', autopct = '%.1f', figsize = (6,6))
# Out:
# <Axes: >

# %% [markdown]
# <br>Flat ST SLOPE - 50% patients</br>
# <br>Down ST SLOPE - 6.9% patients</br>
# <br>Up ST SLOPE - 43% patients</br>

# %%
df.groupby('HeartDisease').size().plot(kind = 'pie', autopct = '%.1f', figsize = (6,6))
# Out:
# <Axes: >

# %% [markdown]
# 55.3% of total patients are diagnosed with heart disease

# %% [markdown]
# ## Violin Plot

# %%
sns.violinplot( x = df["Age"])
# Out:
# <Axes: xlabel='Age'>

# %% [markdown]
# Here , we can analyse that maximum number of heart disease cases are found in age 50-60

# %%
sns.violinplot(y = df['Sex'], x = df['HeartDisease'])
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Sex'>

# %% [markdown]
# <br>This shows:</br>
# Larger number of females has no heart disease whereas Larger number of men has heart disease although this could be because that the data set has more number of males than females

# %%
sns.violinplot(y = df['Age'], x = df['HeartDisease'])
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Age'>

# %% [markdown]
# Patients around age 50 has less cases of heart disease whereas large number of patients around the age of 60 has a heart disease

# %%
sns.violinplot(y = df['Cholesterol'], x = df['HeartDisease'])
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Cholesterol'>

# %% [markdown]
# we can analyse that high cholestrol is propertional to higher chances of HeartDisease

# %% [markdown]
# ## CORRELATION

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
df_1 =df.drop(columns = {"Sex" , "ChestPainType","RestingECG" , "ExerciseAngina" , "ST_Slope"})

# %%
df_1.corr()
# Out:
#                    Age  RestingBP  Cholesterol  FastingBS     MaxHR   Oldpeak  \
# Age           1.000000   0.254399    -0.095282   0.198039 -0.382045  0.258612
# RestingBP     0.254399   1.000000     0.100893   0.070193 -0.112135  0.164803
# Cholesterol  -0.095282   0.100893     1.000000  -0.260974  0.235792  0.050148
# FastingBS     0.198039   0.070193    -0.260974   1.000000 -0.131438  0.052698
# MaxHR        -0.382045  -0.112135     0.235792  -0.131438  1.000000 -0.160691
# Oldpeak       0.258612   0.164803     0.050148   0.052698 -0.160691  1.000000
# HeartDisease  0.282039   0.107589    -0.232741   0.267291 -0.400421  0.403951
#
#               HeartDisease
# Age               0.282039
# RestingBP         0.107589
# Cholesterol      -0.232741
# FastingBS         0.267291
# MaxHR            -0.400421
# Oldpeak           0.403951
# HeartDisease      1.000000

# %%
sns.heatmap(df_1.corr())
# Out:
# <Axes: >
